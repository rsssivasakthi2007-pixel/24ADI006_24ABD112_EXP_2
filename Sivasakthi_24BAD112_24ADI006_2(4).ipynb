# %%
print("Roll No: 24BAD112")
print("Name: SIVASAKTHI S")

import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Student Details
student_name = "SIVASAKTHI"
roll_no = "24BAD112"

# Create Experiment Folder
base_path = "DL_Experiment_24BAD112"
os.makedirs(base_path, exist_ok=True)

print("Experiment folder created successfully")
print("Folder Path:", os.path.abspath(base_path))
# Load MNIST Dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Preprocess Data
x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

# Build Deep Learning Model
model = keras.Sequential([
    keras.Input(shape=(784,)),
    layers.Dense(128, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])
# Compile Model
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Train Model

print("\nTraining Model...")

model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=128,
    validation_data=(x_test, y_test),
    verbose=1
)

# Evaluate Model
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

print("\nModel Evaluation")
print("Test Loss :", round(loss, 4))
print("Test Accuracy :", round(accuracy * 100, 2), "%")


# Save Model
model_path = os.path.join(
    base_path,
    "mnist_deep_learning_model.keras"
)

model.save(model_path)

print("\nTrained model saved successfully")
print("Model Path:", model_path)

# Create README File
readme_content = f"""
# Deep Learning Experiment Management

Student Name : {student_name}
Roll Number  : {roll_no}

Dataset Used : MNIST Handwritten Digits

Model Architecture:
- Input Layer : 784 neurons
- Hidden Layer 1 : 128 neurons (ReLU)
- Hidden Layer 2 : 64 neurons (ReLU)
- Output Layer : 10 neurons (Softmax)

Optimizer : Adam
Loss Function : Sparse Categorical Crossentropy
Epochs : 5
Batch Size : 128

Test Accuracy : {accuracy*100:.2f}%
"""

readme_path = os.path.join(
    base_path,
    "README.md"
)

with open(readme_path, "w") as file:
    file.write(readme_content)

print("README.md created successfully")
print("README Path:", readme_path)

# Display Folder Contents
print("\nFiles in Experiment Folder:")

for file_name in os.listdir(base_path):
    print(file_name)

print("\nExperiment completed successfully.")
# Out:
# Roll No: 24BAD112
# Name: SIVASAKTHI S
# Experiment folder created successfully
# Folder Path: /content/DL_Experiment_24BAD112
#
# Training Model...
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9010 - loss: 0.3496 - val_accuracy: 0.9496 - val_loss: 0.1698
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9593 - loss: 0.1393 - val_accuracy: 0.9618 - val_loss: 0.1243
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9716 - loss: 0.0962 - val_accuracy: 0.9710 - val_loss: 0.0925
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9780 - loss: 0.0738 - val_accuracy: 0.9741 - val_loss: 0.0821
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9822 - loss: 0.0577 - val_accuracy: 0.9746 - val_loss: 0.0790
#
# Model Evaluation
# Test Loss : 0.079
# Test Accuracy : 97.46 %
#
# Trained model saved successfully
# Model Path: DL_Experiment_24BAD112/mnist_deep_learning_model.keras
# README.md created successfully
# README Path: DL_Experiment_24BAD112/README.md
#
# Files in Experiment Folder:
# README.md
# mnist_deep_learning_model.keras
#
# Experiment completed successfully.
